# %% [markdown]
# Example 1: Manage a todo List - Create a todo list to keep track of tasks

# %%
to_do_list = ["Buy Groceries", "Clean the house", "Pay bills"]

## Adding to task 
to_do_list.append("Schedule meeting")
to_do_list.append("Go for a run")

## Removing a completed task
to_do_list.remove("Clean the house")

## Check if a task is in the list or not
if "Pay bills" in to_do_list:
    print("Don't forget to pay the bills")

print("To Do list remaining : ")
for task in to_do_list:
    print(f"> {task}")
# Out:
# Don't forget to pay the bills
# To Do list remaining :
# > Buy Groceries
# > Pay bills
# > Schedule meeting
# > Go for a run

# %% [markdown]
# Example 2 : Organizing Student Grades - Create a list to store and calculate average grades for students

# %%
grades = [90,29,44,78,43,98,83,67]

#Adding a new grade 
grades.append(64)

## Calculating the average grade
average_grade = sum(grades)/len(grades)
print(f"Average grade is : {average_grade:.2f}")

## Finding the highest and lowest grade 
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"The highest grade is : {highest_grade}")
print(f"The lowest grade is : {lowest_grade}")
# Out:
# Average grade is : 66.22
# The highest grade is : 98
# The lowest grade is : 29

# %% [markdown]
# Example 3 : Managing an inventory : Use a list to manage inventory items in a store

# %%
inventory = ["oranges", "apples", "bananas", "grapes", "cherry"]

## Adding an item
inventory.append("strawberries")

## Removing an item 
inventory.remove("cherry")

# checking if an item is in inventory or not 
item = "oranges"
if item in inventory:
    print(f"{item} in stock")
else :
    print(f"{item} out of stock")

print("Inventory List : ")
for items in inventory:
    print(f"- {items}")
# Out:
# oranges in stock
# Inventory List :
# - oranges
# - apples
# - bananas
# - grapes
# - strawberries

# %% [markdown]
# Example 4 : Collecting user Feedback - Use a list to collect and analyze user feedback

# %%
## Collecting User Feedback 
feedbacks = ["Great Service", "Very Satisfied", "COuld be better", "Excellent Experience"]

## Adding new Feedback 
feedbacks.append("Not happy with the service")

## Counting Specific Feedback 
positive_feedback_count = sum(1 for comment in feedbacks if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback count : {positive_feedback_count}")

## Printing all the feedbacks
print("User Feedback : ")
for comment in feedbacks:
    print(f"- {comment}")
# Out:
# Positive Feedback count : 2
# User Feedback :
# - Great Service
# - Very Satisfied
# - COuld be better
# - Excellent Experience
# - Not happy with the service
