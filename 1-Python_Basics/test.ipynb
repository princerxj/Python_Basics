# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ### Python Example

# %%
print("hello world")
# Out:
# hello world

# %%
print("Hello, My name is Prince Raj")
# Out:
# Hello, My name is Prince Raj

# %%
### Basic Syntax Rules in Python 
## Case Sensitivity - Python is Case-Sensitive
name = "Krish"
Name = "Naik"
print(name)
print(Name)
# Out:
# Krish
# Naik

# %%
## Indentation in Python 
## It is used to define the block of code, Consistent use of spaces is required .

age = 32
if age >= 18:
    print("You can vote in India")
# Out:
# You can vote in India

# %%
## Line Continuation in Python 
total = 1+2+3+4+\
4+5
print(total)
# Out:
# 19

# %%
## Multiple Statements on a single line 
a = 4; b = 5; c = a + b
print(c)
# Out:
# 9

# %%
## Understanding Semantics in Python 
age = 32 # age is an integer
name = "Prince" #name is a String

# %%
type(name)
# Out:
# str

# %%
### Type Interfrence
variable=10
print(type(variable))
variable="Prince"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
