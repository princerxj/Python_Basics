# %%
## If statement - It evaluates a condition 
age = 20
if age >= 18 :
    print("You can vote")
# Out:
# You can vote

# %%
## else - get executed when the if the statement in the if block is false
age = 17
if age >= 18 :
    print("You can vote")
else :
    print("You cannot Vote")
# Out:
# You cannot Vote

# %%
## elif statements - It allows to check multiple conditions (else if) 
age = 18
if age < 13 : 
    print("You are a child")
elif age < 18 :
    print("You are a teenager")
else :
    print("You are an adult")
# Out:
# You are an adult

# %%
## Nested Conditional Statements 
## We can place one or more if, elif or else statements inside another if, elif, else conditional statement 
num = int(input("Enter a number"))
if num >= 0:
    print("The number is positive")
    if num % 2 == 0 :
        print("Even number")
    else :
        print("Odd Number")
else :
    print("Negative Number")
# Out:
# The number is positive
# Odd Number
