# %%
## 5.1 - Assignment 1
import math 
print(math.sqrt(25))
print(math.sin(math.pi/2))
# Out:
# 5.0
# 1.0

# %%
## Assignment 2
import datetime as dt 
current_time = dt.datetime.now()
print(current_time)
# Out:
# 2025-12-17 09:14:22.587120

# %%
## Assignment 3
from random import randint
print(randint(1,100))
# Out:
# 26

# %%
## Assignment 4
from math import sqrt, pow
print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %%
## Assignment 5
try :
    import pandas
    print("Pandas is present")
except ImportError:
    print("Pandas library is not present")
# Out:
# Pandas library is not present

# %%
#5.2
## Assignment 6 
import os
os.mkdir("New_Dir")
os.listdir()
# os.rmdir("New_Dir")
# Out:
# ['5.1-import.ipynb',
#  '5.2-StandardLibrary.ipynb',
#  'destination.txt',
#  'example.csv',
#  'myfile.txt',
#  'New_Dir',
#  'package',
#  'packagesolution.ipynb',
#  'packagesquestion.ipynb',
#  'source.txt',
#  'test.py',
#  'test_dir']

# %%
## Assignment 7
import sys
print(sys.argv) ## Command Line arguments passed to the script
print(sys.version) ## Prints the python version
# Out:
# ['d:\\Python_Basics\\venv\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\Asus\\AppData\\Roaming\\jupyter\\runtime\\kernel-v342f26a21c5fe87b4e28a7dd74e2e956cbc94426c.json']
# 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 17:20:38) [MSC v.1916 64 bit (AMD64)]

# %%
## Assignment 8
print(math.gcd(90,170))
print(math.factorial(5))
# Out:
# 10
# 120

# %%
## Assignment 9
import datetime
print(datetime.datetime.now().date()) ## Prints the current Date
print(datetime.datetime.now().date() - datetime.timedelta(days=100))
print(datetime.datetime(2024, 12, 24).strftime("%A"))
# Out:
# 2025-12-17
# 2025-09-08
# Tuesday

# %%
## Assignment 10
import random
random_numbers = [random.randint(1, 50) for _ in range(5)]
print(random_numbers)
lst = [1, 2, 3, 4, 5]
random.shuffle(lst)
print(lst)
# Out:
# [30, 10, 43, 43, 26]
# [1, 5, 3, 4, 2]

# %%
#5.3
## Assignment 11
from mypackage import module1, module2

print(module1.addition(1,9))
print(module2.mul(7,6))
# Out:
# 10
# 42

# %%
## Assignment 12
from mypackage import module1, module2

print(module1.addition(13,9))
print(module2.mul(7,16))
# Out:
# 22
# 112

# %%
## Assignment 13
import mypackage
print(mypackage.module1.addition(1,2))
print(mypackage.module2.mul(4,5))
# Out:
# 3
# 20

# %%
## Assignment 14
import mypackage
print(mypackage.module2.mul(1,9))
print(mypackage.module1.addition(1,2))
# Out:
# 9
# 3

# %%
## Assignment 15 
try :
    from mypackage import subtraction
    print("Function Found")
except ImportError:
    print("Function not found")
# Out:
# Function not found
