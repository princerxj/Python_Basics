# %%
import array 
arr = array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math 
print(math.sqrt(9))
print(math.pi)
# Out:
# 3.0
# 3.141592653589793

# %%
## random 
import random 
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 10
# banana

# %%
### File and Directory access is done using OS library 
import os
print(os.getcwd())
# Out:
# d:\Python_Basics\5-Importing_Modules

# %%
## Creating a directory
os.mkdir('test_dir')

# %%
## Creating a file
with open('myfile.txt', 'w') as fp:
    pass

# %%
## High level operation on files and collection of files 
import shutil 
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization 
import json 
data = {'name':'Krish', 'age' : 25}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
## csv 
import csv 
with open('example.csv', mode='w', newline='') as file :
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish', 32])
    writer.writerow(['Prince', 20])

with open('example.csv', mode='r') as file :
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']
# ['Prince', '20']

# %%
## datetime
from datetime import datetime, timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2025-12-17 09:03:20.423674
# 2025-12-16 09:03:20.423674

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1765942446.770091
# 1765942448.7721941

# %%
## regular expressions - It helps to match patterns over a sentence , file or entire dataset 
import re 

pattern = r'\d+'
text = "There are 123 apples"
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
