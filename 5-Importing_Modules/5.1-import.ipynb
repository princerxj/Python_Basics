# %%
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(9))
print(pi)
# Out:
# 3.0
# 3.141592653589793

# %%
import numpy as np

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sqrt(8))
print(cos(pi))
# Out:
# 2.8284271247461903
# -1.0

# %%
from package.maths import addition
print(addition(9,8))
# Out:
# 17

# %%
from package import maths
maths.addition(9,3)
# Out:
# 12
